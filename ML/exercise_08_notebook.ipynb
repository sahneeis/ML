# %%
import copy
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms

print(torch.__version__)        # 查看 PyTorch 版本
print(torch.version.cuda)       # 查看 CUDA 版本
print(torch.cuda.is_available())  # 查看是否检测到 CUDA 可用

print(torch.cuda.is_available())  # 如果返回 True，说明可以使用 GPU
print(torch.cuda.current_device())  # 获取当前 GPU 的索引
print(torch.cuda.device(0))  # 获取 GPU 设备信息
print(torch.cuda.get_device_name(0))  # 获取 GPU 设备名称
# Out:
# 2.5.1
# 12.1
# True
# True
# 0
# <torch.cuda.device object at 0x000001CB47FDDD30>
# NVIDIA GeForce RTX 4060 Laptop GPU

# %% [markdown]
# # PyTorch
# In this notebook you will gain some hands-on experience with [PyTorch](https://pytorch.org/), one of the major frameworks for deep learning. To install PyTorch. follow [the official installation instructions](https://pytorch.org/get-started/locally/). Make sure that you select the correct OS & select the version with CUDA if your computer supports it.
# If you do not have an Nvidia GPU, you can install the CPU version by setting `CUDA` to `None`.
# However, in this case we recommend using [Google Colab](https://colab.research.google.com/).
# Make sure that you enable GPU acceleration in `Runtime > Change runtime type`.
#
# You will start by re-implementing some common features of deep neural networks (dropout and batch normalization) and then implement a very popular modern architecture for image classification (ResNet) and improve its training loop.

# %% [markdown]
# # 1. Dropout
# Dropout is a form of regularization for neural networks. It works by randomly setting activations (values) to 0, each one with equal probability `p`. The values are then scaled by a factor $\frac{1}{1-p}$ to conserve their mean.
#
# Dropout effectively trains a pseudo-ensemble of models with stochastic gradient descent. During evaluation we want to use the full ensemble and therefore have to turn off dropout. Use `self.training` to check if the model is in training or evaluation mode.
#
# Do not use any dropout implementation from PyTorch for this!

# %%
class Dropout(nn.Module):
    """
    Dropout, as discussed in the lecture and described here:
    https://pytorch.org/docs/stable/nn.html#torch.nn.Dropout
    
    Args:
        p: float, dropout probability
    """
    def __init__(self, p):
        super().__init__()
        # assert 0 <= p <= 1, "Dropout rate p must be between 0 and 1."
        self.p = p
        
    def forward(self, input):
        """
        The module's forward pass.
        This has to be implemented for every PyTorch module.
        PyTorch then automatically generates the backward pass
        by dynamically generating the computational graph during
        execution.
        
        Args:
            input: PyTorch tensor, arbitrary shape

        Returns:
            PyTorch tensor, same shape as input
        """
        
        # TODO: Set values randomly to 0.
        # Check if we are in training mode
        if self.training:
            # Create a mask with the same shape as the input
            mask = (torch.rand_like(input) > self.p).float()  # Random mask based on p
            return input * mask / (1 - self.p)  # Scale the input to maintain the expected value
        else:
            # If not in training, return the input as is (no dropout applied)
            return input

# %%
# Test dropout
test = torch.rand(10_000)
dropout = Dropout(0.2)
test_dropped = dropout(test)

# These assertions can in principle fail due to bad luck, but
# if implemented correctly they should almost always succeed.
assert np.isclose(test_dropped.mean().item(), test.mean().item(), atol=1e-2)
assert np.isclose((test_dropped > 0).float().mean().item(), 0.8, atol=1e-2)

# %% [markdown]
# # 2. Batch normalization
# Batch normalization is a trick use to smoothen the loss landscape and improve training. It is defined as the function
# $$y = \frac{x - \mu_x}{\sigma_x + \epsilon} \cdot \gamma + \beta$$,
# where $\gamma$ and $\beta$ and learnable parameters and $\epsilon$ is a some small number to avoid dividing by zero. The Statistics $\mu_x$ and $\sigma_x$ are taken separately for each feature. In a CNN this means averaging over the batch and all pixels.
#
# Do not use any batch normalization implementation from PyTorch for this!

# %%
class BatchNorm(nn.Module):
    """
    Batch normalization, as discussed in the lecture and similar to
    https://pytorch.org/docs/stable/nn.html#torch.nn.BatchNorm1d
    
    Only uses batch statistics (no running mean for evaluation).
    Batch statistics are calculated for a single dimension.
    Gamma is initialized as 1, beta as 0.
    
    Args:
        num_features: Number of features to calculate batch statistics for.
    """
    def __init__(self, num_features):
        super().__init__()
        
        # TODO: Initialize the required parameters
        # Initialize the required parameters
        self.gamma = nn.Parameter(torch.ones(1, num_features, 1))  # Shape: [1, C, 1]
        self.beta = nn.Parameter(torch.zeros(1, num_features, 1))  # Shape: [1, C, 1]
        
    def forward(self, input):
        """
        Batch normalization over the dimension C of (N, C, L).
        
        Args:
            input: PyTorch tensor, shape [N, C, L]
            
        Return:
            PyTorch tensor, same shape as input
        """
        eps = 1e-5
        
        # TODO: Implement the required transformation
        assert len(input.shape) == 3, "Input must have shape [N, C, L]"
        mean = input.mean(dim=(0, 2), keepdim=True)
        var = input.var(dim=(0, 2), keepdim=True, unbiased=False)
        # Normalize the input
        input_normalized = (input - mean) / torch.sqrt(var + eps)

        # Scale and shift using learnable parameters gamma and beta
        output = self.gamma.view(1, -1, 1) * input_normalized + self.beta.view(1, -1, 1)

        return output

# %%
# Tests the batch normalization implementation
torch.random.manual_seed(42)
test = torch.randn(8, 2, 4)

b1 = BatchNorm(2)
test_b1 = b1(test)

b2 = nn.BatchNorm1d(2, affine=False, track_running_stats=False)
test_b2 = b2(test)

assert torch.allclose(test_b1, test_b2, rtol=0.02)

# %% [markdown]
# # 3. ResNet
# ResNet is the models that first introduced residual connections (a form of skip connections). It is a rather simple, but successful and very popular architecture. In this part of the exercise we will re-implement it step by step.
#
# Note that there is also an [improved version of ResNet](https://arxiv.org/abs/1603.05027) with optimized residual blocks. Here we will implement the [original version](https://arxiv.org/abs/1512.03385) for CIFAR-10. Your dropout and batchnorm implementations won't help you here. Just use PyTorch's own layers.

# %% [markdown]
# This is just a convenience function to make e.g. `nn.Sequential` more flexible. It is e.g. useful in combination with `x.squeeze()`.

# %%
class Lambda(nn.Module):
    def __init__(self, func):
        super().__init__()
        self.func = func

    def forward(self, x):
        return self.func(x)

# %% [markdown]
# We begin by implementing the residual blocks. The block is illustrated by this sketch:
#
# ![Residual connection](img/residual_connection.png)
#
# Note that we use 'SAME' padding, no bias, and batch normalization after each convolution. You do not need `nn.Sequential` here. The skip connection is already implemented as `self.skip`. It can handle different strides and increases in the number of channels.

# %%
class ResidualBlock(nn.Module):
    """
    The residual block used by ResNet.
    
    Args:
        in_channels: The number of channels (feature maps) of the incoming embedding
        out_channels: The number of channels after the first convolution
        stride: Stride size of the first convolution, used for downsampling
    """
    
    def __init__(self, in_channels, out_channels, stride=1):
        
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU()
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(out_channels)
        
        # Skip connection for dimension matching
        self.skip = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.skip = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride),
                nn.BatchNorm2d(out_channels)
            )
        # TODO: Initialize the required layers
        
    def forward(self, input):
        # TODO: Execute the required layers and functions
        # Pass input through the first convolutional layer
        out = self.conv1(input)
        out = self.bn1(out)#batch norm
        out = self.relu(out)
        
        # Pass the output through the second convolutional layer
        out = self.conv2(out)
        out = self.bn2(out)
        
        # Add the skip connection
        skip = self.skip(input)
        
        # The output of the residual block is the sum of the processed input and the skip connection
        out += skip
        
        # Apply the ReLU activation after the addition of the skip connection
        out = self.relu(out)
        
        return out

# %% [markdown]
# Next we implement a stack of residual blocks for convenience. The first layer in the block is the one changing the number of channels and downsampling. You can use `nn.ModuleList` to use a list of child modules.

# %%
class ResidualStack(nn.Module):
    """
    A stack of residual blocks.

    Args:
        in_channels: The number of channels (feature maps) of the incoming embedding
        out_channels: The number of channels after the first layer
        stride: Stride size of the first layer, used for downsampling
        num_blocks: Number of residual blocks
    """

    def __init__(self, in_channels, out_channels, stride, num_blocks):
        super().__init__()

        # TODO: Initialize the required layers (blocks)
        # The first residual block handles channel change and downsampling
        self.blocks = nn.ModuleList()
        self.blocks.append(ResidualBlock(in_channels, out_channels, stride=stride))

        # Subsequent blocks maintain the same number of channels and no downsampling (stride=1)
        for _ in range(1, num_blocks):
            self.blocks.append(ResidualBlock(out_channels, out_channels, stride=1))

    def forward(self, input):
        # TODO: Execute the layers (blocks)
        x = input
        for block in self.blocks:
            x = block(x)  # Apply each residual block sequentially
        return x

# %% [markdown]
# Now we are finally ready to implement the full model! To do this, use the `nn.Sequential` API and carefully read the following paragraph from the paper (Fig. 3 is not important):
#
# ![ResNet CIFAR10 description](img/resnet_cifar10_description.png)
#
# Note that a convolution layer is always convolution + batch norm + activation (ReLU), that each ResidualBlock contains 2 layers, and that you might have to `squeeze` the embedding before the dense (fully-connected) layer.

# %%
# TODO: Implement ResNet via nn.Sequential
class ResNet(nn.Module):
    """
    ResNet for CIFAR10.
    """
    def __init__(self, n, num_classes):
        super().__init__()
        self.model = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False),  # Input channels changed to 3
            nn.BatchNorm2d(16),
            nn.ReLU(),
            ResidualStack(16, 16, stride=1, num_blocks=n),
            ResidualStack(16, 32, stride=2, num_blocks=n),
            ResidualStack(32, 64, stride=2, num_blocks=n),
            nn.AvgPool2d(kernel_size=8),  # Global average pooling
            Lambda(lambda x: x.squeeze()),  # Squeeze before the dense layer
            nn.Linear(64, num_classes)  # Dense layer with num_classes outputs
        )

    def forward(self, x):
        return self.model(x)

n = 5
num_classes = 10

# Instantiate the model
resnet = ResNet(n, num_classes)  # Using the ResNet class

# Test input
x = torch.randn(8, 3, 32, 32)
output = resnet(x)

print(output.shape)  # Output should be (8, 10)
# Out:
# torch.Size([8, 10])

# %% [markdown]
# Next we need to initialize the weights of our model.

# %%
def initialize_weight(module):
    if isinstance(module, (nn.Linear, nn.Conv2d)):
        nn.init.kaiming_normal_(module.weight, nonlinearity='relu')
    elif isinstance(module, nn.BatchNorm2d):
        nn.init.constant_(module.weight, 1)
        nn.init.constant_(module.bias, 0)
resnet = ResNet(n=5, num_classes = 10)      
resnet.apply(initialize_weight)
print(resnet)
# Out:
# ResNet(
#   (model): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): ResidualStack(
#       (blocks): ModuleList(
#         (0-4): 5 x ResidualBlock(
#           (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#           (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (skip): Sequential()
#         )
#       )
#     )
#     (4): ResidualStack(
#       (blocks): ModuleList(
#         (0): ResidualBlock(
#           (conv1): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (skip): Sequential(
#             (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2))
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1-4): 4 x ResidualBlock(
#           (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (skip): Sequential()
#         )
#       )
#     )
#     (5): ResidualStack(
#       (blocks): ModuleList(
#         (0): ResidualBlock(
#           (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (skip): Sequential(
#             (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2))
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1-4): 4 x ResidualBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (skip): Sequential()
#         )
#       )
#     )
#     (6): AvgPool2d(kernel_size=8, stride=8, padding=0)
#     (7): Lambda()
#     (8): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# # 4. Training
# So now we have a shiny new model, but that doesn't really help when we can't train it. So that's what we do next.
#
# First we need to load the data. Note that we split the official training data into train and validation sets, because you must not look at the test set until you are completely done developing your model and report the final results. Some people don't do this properly, but you should not copy other people's bad habits.

# %%
class CIFAR10Subset(torchvision.datasets.CIFAR10):
    """
    Get a subset of the CIFAR10 dataset, according to the passed indices.
    """
    def __init__(self, *args, idx=None, **kwargs):
        super().__init__(*args, **kwargs)
        
        if idx is None:
            return
        
        self.data = self.data[idx]
        targets_np = np.array(self.targets)
        self.targets = targets_np[idx].tolist()

# %% [markdown]
# We next define transformations that change the images into PyTorch tensors, standardize the values according to the precomputed mean and standard deviation, and provide data augmentation for the training set.

# %%
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, 4),
    transforms.ToTensor(),
    normalize,
])
transform_eval = transforms.Compose([
    transforms.ToTensor(),
    normalize
])

# %%
ntrain = 45_000
train_set = CIFAR10Subset(root='./data', train=True, idx=range(ntrain),
                          download=True, transform=transform_train)
val_set = CIFAR10Subset(root='./data', train=True, idx=range(ntrain, 50_000),
                        download=True, transform=transform_eval)
test_set = torchvision.datasets.CIFAR10(root='./data', train=False,
                                        download=True, transform=transform_eval)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
dataloaders = {}
dataloaders['train'] = torch.utils.data.DataLoader(train_set, batch_size=128,
                                                   shuffle=True, num_workers=0,
                                                   pin_memory=True)
dataloaders['val'] = torch.utils.data.DataLoader(val_set, batch_size=128,
                                                 shuffle=False, num_workers=0,
                                                 pin_memory=True)
dataloaders['test'] = torch.utils.data.DataLoader(test_set, batch_size=128,
                                                  shuffle=False, num_workers=0,
                                                  pin_memory=True)

# %% [markdown]
# Next we push the model to our GPU (if there is one).

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
resnet.to(device);
import torch
print(torch.cuda.is_available())  # 检查 CUDA 是否可用
print(torch.cuda.get_device_name(0))  # 显示 GPU 名称
# Out:
# True
# NVIDIA GeForce RTX 4060 Laptop GPU

# %% [markdown]
# Next we define a helper method that does one epoch of training or evaluation. We have only defined training here, so you need to implement the necessary changes for evaluation!

# %%
def run_epoch(model, optimizer, dataloader, train):
    """
    Run one epoch of training or evaluation.
    
    Args:
        model: The model used for prediction
        optimizer: Optimization algorithm for the model
        dataloader: Dataloader providing the data to run our model on
        train: Whether this epoch is used for training or evaluation
        
    Returns:
        Loss and accuracy in this epoch.
    """
    # TODO: Change the necessary parts to work correctly during evaluation (train=False)
    
    device = next(model.parameters()).device
    print(f"Model is on device: {device}")
    
    # Set the model to training or evaluation mode
    if train:
        model.train()
        print("Model set to TRAINING mode.")
    else:
        model.eval()
        print("Model set to EVALUATION mode.")
    
    epoch_loss = 0.0
    epoch_acc = 0.0
    total_samples = 0

    # Iterate over data
    for batch_idx, (xb, yb) in enumerate(dataloader):
        print(f"\nProcessing batch {batch_idx + 1}/{len(dataloader)}")
        xb, yb = xb.to(device), yb.to(device)
        print(f"Input batch shape: {xb.shape}, Target batch shape: {yb.shape}")

        # Zero the parameter gradients (only in training mode)
        if train:
            optimizer.zero_grad()
            print("Optimizer gradients zeroed.")

        # Forward pass
        with torch.set_grad_enabled(train):  # Disable gradients during evaluation
            pred = model(xb)
            print(f"Prediction shape: {pred.shape}")
            loss = F.cross_entropy(pred, yb)
            print(f"Batch loss: {loss.item():.4f}")

            # Calculate accuracy
            top1 = torch.argmax(pred, dim=1)
            ncorrect = torch.sum(top1 == yb).item()
            print(f"Number of correct predictions in this batch: {ncorrect}/{len(yb)}")

        # Update the loss and accuracy
        epoch_loss += loss.item() * len(yb)
        epoch_acc += ncorrect
        total_samples += len(yb)

        # Backpropagation and optimization (only during training)
        if train:
            loss.backward()
            optimizer.step()
            print("Model parameters updated.")


    # Average loss and accuracy over the dataset
    epoch_loss /= total_samples
    epoch_acc /= total_samples
    
    return epoch_loss, epoch_acc

# %% [markdown]
# Next we implement a method for fitting (training) our model. For many models early stopping can save a lot of training time. Your task is to add early stopping to the loop (based on validation accuracy). Early stopping usually means exiting the training loop if the validation accuracy hasn't improved for `patience` number of steps. Don't forget to save the best model parameters according to validation accuracy. You will need `copy.deepcopy` and the `state_dict` for this.

# %%
def fit(model, optimizer, lr_scheduler, dataloaders, max_epochs, patience):
    """
    Fit the given model on the dataset.

    Args:
        model: The model used for prediction
        optimizer: Optimization algorithm for the model
        lr_scheduler: Learning rate scheduler that improves training
                      in late epochs with learning rate decay
        dataloaders: Dataloaders for training and validation
        max_epochs: Maximum number of epochs for training
        patience: Number of epochs to wait with early stopping the
                  training if validation loss has decreased

    Returns:
        Loss and accuracy in this epoch.
    """

    best_acc = 0
    curr_patience = 0
    best_model_weights = copy.deepcopy(model.state_dict())  # Save the best model weights

    for epoch in range(max_epochs):
        train_loss, train_acc = run_epoch(model, optimizer, dataloaders['train'], train=True)
        lr_scheduler.step()
        print(f"Epoch {epoch + 1: >3}/{max_epochs}, train loss: {train_loss:.2e}, accuracy: {train_acc * 100:.2f}%")

        val_loss, val_acc = run_epoch(model, None, dataloaders['val'], train=False)
        print(f"Epoch {epoch + 1: >3}/{max_epochs}, val loss: {val_loss:.2e}, accuracy: {val_acc * 100:.2f}%")

        # TODO: Add early stopping and save the best weights (in best_model_weights)
        # Early stopping and saving best model weights
        if val_acc > best_acc:
            best_acc = val_acc
            best_model_weights = copy.deepcopy(model.state_dict())  # Save the current best weights
            curr_patience = 0  # Reset patience counter
            print(f"Validation accuracy improved to {best_acc * 100:.2f}%, saving model...")
        else:
            curr_patience += 1  # Increment patience counter
            print(f"No improvement for {curr_patience} epoch(s).")

        # Check for early stopping
        if curr_patience >= patience:
            print(f"Early stopping triggered after {epoch + 1} epochs.")
            break
    model.load_state_dict(best_model_weights)
    print("Training complete. Best validation accuracy: {:.2f}%".format(best_acc * 100))
    return model

# %% [markdown]
# In most cases you should just use the Adam optimizer for training, because it works well out of the box. However, a well-tuned SGD (with momentum) will in most cases outperform Adam. And since the original paper gives us a well-tuned SGD we will just use that.

# %%
optimizer = torch.optim.SGD(resnet.parameters(), lr=0.1, momentum=0.9, weight_decay=1e-4)
lr_scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[100, 150], gamma=0.1)

# Fit model
fit(resnet, optimizer, lr_scheduler, dataloaders, max_epochs=200, patience=50)
# Out:
# Model is on device: cuda:0
# Model set to TRAINING mode.
#
# Processing batch 1/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 3.0641
# Number of correct predictions in this batch: 17/128
# Model parameters updated.
#
# Processing batch 2/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.5967
# Number of correct predictions in this batch: 16/128
# Model parameters updated.
#
# Processing batch 3/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.6893
# Number of correct predictions in this batch: 18/128
# Model parameters updated.
#
# Processing batch 4/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 3.2961
# Number of correct predictions in this batch: 11/128
# Model parameters updated.
#
# Processing batch 5/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 3.2122
# Number of correct predictions in this batch: 23/128
# Model parameters updated.
#
# Processing batch 6/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 3.2465
# Number of correct predictions in this batch: 15/128
# Model parameters updated.
#
# Processing batch 7/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.7191
# Number of correct predictions in this batch: 18/128
# Model parameters updated.
#
# Processing batch 8/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.5382
# Number of correct predictions in this batch: 16/128
# Model parameters updated.
#
# Processing batch 9/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.5990
# Number of correct predictions in this batch: 24/128
# Model parameters updated.
#
# Processing batch 10/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.6011
# Number of correct predictions in this batch: 21/128
# Model parameters updated.
#
# Processing batch 11/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.3363
# Number of correct predictions in this batch: 27/128
# Model parameters updated.
#
# Processing batch 12/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.3980
# Number of correct predictions in this batch: 27/128
# Model parameters updated.
#
# Processing batch 13/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.5217
# Number of correct predictions in this batch: 17/128
# Model parameters updated.
#
# Processing batch 14/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.2932
# Number of correct predictions in this batch: 18/128
# Model parameters updated.
#
# Processing batch 15/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.3622
# Number of correct predictions in this batch: 23/128
# Model parameters updated.
#
# Processing batch 16/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.3261
# Number of correct predictions in this batch: 20/128
# Model parameters updated.
#
# Processing batch 17/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.3662
# Number of correct predictions in this batch: 27/128
# Model parameters updated.
#
# Processing batch 18/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.0027
# Number of correct predictions in this batch: 34/128
# Model parameters updated.
#
# Processing batch 19/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.0321
# Number of correct predictions in this batch: 27/128
# Model parameters updated.
#
# Processing batch 20/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.1932
# Number of correct predictions in this batch: 16/128
# Model parameters updated.
#
# Processing batch 21/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.1021
# Number of correct predictions in this batch: 28/128
# Model parameters updated.
#
# Processing batch 22/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.1924
# Number of correct predictions in this batch: 20/128
# Model parameters updated.
#
# Processing batch 23/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.0322
# Number of correct predictions in this batch: 30/128
# Model parameters updated.
#
# Processing batch 24/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.1074
# Number of correct predictions in this batch: 29/128
# Model parameters updated.
#
# Processing batch 25/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.1933
# Number of correct predictions in this batch: 30/128
# Model parameters updated.
#
# Processing batch 26/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.2857
# Number of correct predictions in this batch: 23/128
# Model parameters updated.
#
# Processing batch 27/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.0034
# Number of correct predictions in this batch: 25/128
# Model parameters updated.
#
# Processing batch 28/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.1330
# Number of correct predictions in this batch: 27/128
# Model parameters updated.
#
# Processing batch 29/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.0610
# Number of correct predictions in this batch: 30/128
# Model parameters updated.
#
# Processing batch 30/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.1301
# Number of correct predictions in this batch: 20/128
# Model parameters updated.
#
# Processing batch 31/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.0897
# Number of correct predictions in this batch: 27/128
# Model parameters updated.
#
# Processing batch 32/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.2034
# Number of correct predictions in this batch: 19/128
# Model parameters updated.
#
# Processing batch 33/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.9962
# Number of correct predictions in this batch: 31/128
# Model parameters updated.
#
# Processing batch 34/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.0600
# Number of correct predictions in this batch: 27/128
# Model parameters updated.
#
# Processing batch 35/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.9202
# Number of correct predictions in this batch: 34/128
# Model parameters updated.
#
# Processing batch 36/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8834
# Number of correct predictions in this batch: 33/128
# Model parameters updated.
#
# Processing batch 37/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.0481
# Number of correct predictions in this batch: 29/128
# Model parameters updated.
#
# Processing batch 38/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.0583
# Number of correct predictions in this batch: 28/128
# Model parameters updated.
#
# Processing batch 39/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.9806
# Number of correct predictions in this batch: 27/128
# Model parameters updated.
#
# Processing batch 40/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8646
# Number of correct predictions in this batch: 45/128
# Model parameters updated.
#
# Processing batch 41/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8583
# Number of correct predictions in this batch: 31/128
# Model parameters updated.
#
# Processing batch 42/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8690
# Number of correct predictions in this batch: 32/128
# Model parameters updated.
#
# Processing batch 43/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.1109
# Number of correct predictions in this batch: 21/128
# Model parameters updated.
#
# Processing batch 44/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.0688
# Number of correct predictions in this batch: 30/128
# Model parameters updated.
#
# Processing batch 45/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8988
# Number of correct predictions in this batch: 40/128
# Model parameters updated.
#
# Processing batch 46/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8763
# Number of correct predictions in this batch: 39/128
# Model parameters updated.
#
# Processing batch 47/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.9056
# Number of correct predictions in this batch: 33/128
# Model parameters updated.
#
# Processing batch 48/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.9334
# Number of correct predictions in this batch: 34/128
# Model parameters updated.
#
# Processing batch 49/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.1168
# Number of correct predictions in this batch: 35/128
# Model parameters updated.
#
# Processing batch 50/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.9226
# Number of correct predictions in this batch: 43/128
# Model parameters updated.
#
# Processing batch 51/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.9458
# Number of correct predictions in this batch: 32/128
# Model parameters updated.
#
# Processing batch 52/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.1253
# Number of correct predictions in this batch: 19/128
# Model parameters updated.
#
# Processing batch 53/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.9465
# Number of correct predictions in this batch: 31/128
# Model parameters updated.
#
# Processing batch 54/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.0073
# Number of correct predictions in this batch: 28/128
# Model parameters updated.
#
# Processing batch 55/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.9550
# Number of correct predictions in this batch: 30/128
# Model parameters updated.
#
# Processing batch 56/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8768
# Number of correct predictions in this batch: 34/128
# Model parameters updated.
#
# Processing batch 57/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.0548
# Number of correct predictions in this batch: 31/128
# Model parameters updated.
#
# Processing batch 58/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.9846
# Number of correct predictions in this batch: 23/128
# Model parameters updated.
#
# Processing batch 59/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8911
# Number of correct predictions in this batch: 36/128
# Model parameters updated.
#
# Processing batch 60/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.9120
# Number of correct predictions in this batch: 32/128
# Model parameters updated.
#
# Processing batch 61/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.9497
# Number of correct predictions in this batch: 46/128
# Model parameters updated.
#
# Processing batch 62/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8030
# Number of correct predictions in this batch: 44/128
# Model parameters updated.
#
# Processing batch 63/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.9704
# Number of correct predictions in this batch: 36/128
# Model parameters updated.
#
# Processing batch 64/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.9203
# Number of correct predictions in this batch: 37/128
# Model parameters updated.
#
# Processing batch 65/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.9117
# Number of correct predictions in this batch: 31/128
# Model parameters updated.
#
# Processing batch 66/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8201
# Number of correct predictions in this batch: 43/128
# Model parameters updated.
#
# Processing batch 67/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8825
# Number of correct predictions in this batch: 34/128
# Model parameters updated.
#
# Processing batch 68/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8525
# Number of correct predictions in this batch: 41/128
# Model parameters updated.
#
# Processing batch 69/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8630
# Number of correct predictions in this batch: 33/128
# Model parameters updated.
#
# Processing batch 70/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8582
# Number of correct predictions in this batch: 33/128
# Model parameters updated.
#
# Processing batch 71/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8828
# Number of correct predictions in this batch: 33/128
# Model parameters updated.
#
# Processing batch 72/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8356
# Number of correct predictions in this batch: 33/128
# Model parameters updated.
#
# Processing batch 73/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7804
# Number of correct predictions in this batch: 40/128
# Model parameters updated.
#
# Processing batch 74/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.9057
# Number of correct predictions in this batch: 38/128
# Model parameters updated.
#
# Processing batch 75/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8026
# Number of correct predictions in this batch: 38/128
# Model parameters updated.
#
# Processing batch 76/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8411
# Number of correct predictions in this batch: 41/128
# Model parameters updated.
#
# Processing batch 77/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8085
# Number of correct predictions in this batch: 46/128
# Model parameters updated.
#
# Processing batch 78/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7596
# Number of correct predictions in this batch: 35/128
# Model parameters updated.
#
# Processing batch 79/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8295
# Number of correct predictions in this batch: 44/128
# Model parameters updated.
#
# Processing batch 80/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8328
# Number of correct predictions in this batch: 43/128
# Model parameters updated.
#
# Processing batch 81/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8536
# Number of correct predictions in this batch: 40/128
# Model parameters updated.
#
# Processing batch 82/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8076
# Number of correct predictions in this batch: 40/128
# Model parameters updated.
#
# Processing batch 83/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.9280
# Number of correct predictions in this batch: 39/128
# Model parameters updated.
#
# Processing batch 84/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8178
# Number of correct predictions in this batch: 29/128
# Model parameters updated.
#
# Processing batch 85/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8511
# Number of correct predictions in this batch: 37/128
# Model parameters updated.
#
# Processing batch 86/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8625
# Number of correct predictions in this batch: 37/128
# Model parameters updated.
#
# Processing batch 87/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8477
# Number of correct predictions in this batch: 42/128
# Model parameters updated.
#
# Processing batch 88/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8382
# Number of correct predictions in this batch: 41/128
# Model parameters updated.
#
# Processing batch 89/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8192
# Number of correct predictions in this batch: 41/128
# Model parameters updated.
#
# Processing batch 90/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7738
# Number of correct predictions in this batch: 51/128
# Model parameters updated.
#
# Processing batch 91/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7574
# Number of correct predictions in this batch: 42/128
# Model parameters updated.
#
# Processing batch 92/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8340
# Number of correct predictions in this batch: 30/128
# Model parameters updated.
#
# Processing batch 93/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8144
# Number of correct predictions in this batch: 44/128
# Model parameters updated.
#
# Processing batch 94/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8253
# Number of correct predictions in this batch: 48/128
# Model parameters updated.
#
# Processing batch 95/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7914
# Number of correct predictions in this batch: 32/128
# Model parameters updated.
#
# Processing batch 96/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8493
# Number of correct predictions in this batch: 31/128
# Model parameters updated.
#
# Processing batch 97/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7515
# Number of correct predictions in this batch: 35/128
# Model parameters updated.
#
# Processing batch 98/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8626
# Number of correct predictions in this batch: 37/128
# Model parameters updated.
#
# Processing batch 99/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7509
# Number of correct predictions in this batch: 38/128
# Model parameters updated.
#
# Processing batch 100/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7285
# Number of correct predictions in this batch: 49/128
# Model parameters updated.
#
# Processing batch 101/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7779
# Number of correct predictions in this batch: 40/128
# Model parameters updated.
#
# Processing batch 102/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 2.0370
# Number of correct predictions in this batch: 34/128
# Model parameters updated.
#
# Processing batch 103/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7569
# Number of correct predictions in this batch: 49/128
# Model parameters updated.
#
# Processing batch 104/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7152
# Number of correct predictions in this batch: 38/128
# Model parameters updated.
#
# Processing batch 105/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7957
# Number of correct predictions in this batch: 49/128
# Model parameters updated.
#
# Processing batch 106/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8889
# Number of correct predictions in this batch: 36/128
# Model parameters updated.
#
# Processing batch 107/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7575
# Number of correct predictions in this batch: 47/128
# Model parameters updated.
#
# Processing batch 108/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7855
# Number of correct predictions in this batch: 41/128
# Model parameters updated.
#
# Processing batch 109/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7672
# Number of correct predictions in this batch: 42/128
# Model parameters updated.
#
# Processing batch 110/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.6964
# Number of correct predictions in this batch: 49/128
# Model parameters updated.
#
# Processing batch 111/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8396
# Number of correct predictions in this batch: 42/128
# Model parameters updated.
#
# Processing batch 112/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8015
# Number of correct predictions in this batch: 41/128
# Model parameters updated.
#
# Processing batch 113/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7903
# Number of correct predictions in this batch: 43/128
# Model parameters updated.
#
# Processing batch 114/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7573
# Number of correct predictions in this batch: 44/128
# Model parameters updated.
#
# Processing batch 115/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8124
# Number of correct predictions in this batch: 37/128
# Model parameters updated.
#
# Processing batch 116/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.6325
# Number of correct predictions in this batch: 50/128
# Model parameters updated.
#
# Processing batch 117/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8277
# Number of correct predictions in this batch: 42/128
# Model parameters updated.
#
# Processing batch 118/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.6862
# Number of correct predictions in this batch: 52/128
# Model parameters updated.
#
# Processing batch 119/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.6169
# Number of correct predictions in this batch: 44/128
# Model parameters updated.
#
# Processing batch 120/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7108
# Number of correct predictions in this batch: 46/128
# Model parameters updated.
#
# Processing batch 121/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.9632
# Number of correct predictions in this batch: 42/128
# Model parameters updated.
#
# Processing batch 122/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.5310
# Number of correct predictions in this batch: 52/128
# Model parameters updated.
#
# Processing batch 123/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.6725
# Number of correct predictions in this batch: 40/128
# Model parameters updated.
#
# Processing batch 124/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.6441
# Number of correct predictions in this batch: 51/128
# Model parameters updated.
#
# Processing batch 125/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.9345
# Number of correct predictions in this batch: 38/128
# Model parameters updated.
#
# Processing batch 126/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8100
# Number of correct predictions in this batch: 42/128
# Model parameters updated.
#
# Processing batch 127/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.5782
# Number of correct predictions in this batch: 57/128
# Model parameters updated.
#
# Processing batch 128/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7476
# Number of correct predictions in this batch: 56/128
# Model parameters updated.
#
# Processing batch 129/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.6384
# Number of correct predictions in this batch: 49/128
# Model parameters updated.
#
# Processing batch 130/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7901
# Number of correct predictions in this batch: 35/128
# Model parameters updated.
#
# Processing batch 131/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7463
# Number of correct predictions in this batch: 41/128
# Model parameters updated.
#
# Processing batch 132/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.6875
# Number of correct predictions in this batch: 45/128
# Model parameters updated.
#
# Processing batch 133/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7238
# Number of correct predictions in this batch: 49/128
# Model parameters updated.
#
# Processing batch 134/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7149
# Number of correct predictions in this batch: 42/128
# Model parameters updated.
#
# Processing batch 135/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8995
# Number of correct predictions in this batch: 37/128
# Model parameters updated.
#
# Processing batch 136/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7288
# Number of correct predictions in this batch: 40/128
# Model parameters updated.
#
# Processing batch 137/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.5904
# Number of correct predictions in this batch: 51/128
# Model parameters updated.
#
# Processing batch 138/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7607
# Number of correct predictions in this batch: 46/128
# Model parameters updated.
#
# Processing batch 139/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7613
# Number of correct predictions in this batch: 47/128
# Model parameters updated.
#
# Processing batch 140/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8312
# Number of correct predictions in this batch: 43/128
# Model parameters updated.
#
# Processing batch 141/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.6946
# Number of correct predictions in this batch: 49/128
# Model parameters updated.
#
# Processing batch 142/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.6341
# Number of correct predictions in this batch: 57/128
# Model parameters updated.
#
# Processing batch 143/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.6510
# Number of correct predictions in this batch: 46/128
# Model parameters updated.
#
# Processing batch 144/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8328
# Number of correct predictions in this batch: 44/128
# Model parameters updated.
#
# Processing batch 145/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7545
# Number of correct predictions in this batch: 35/128
# Model parameters updated.
#
# Processing batch 146/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7019
# Number of correct predictions in this batch: 44/128
# Model parameters updated.
#
# Processing batch 147/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.5794
# Number of correct predictions in this batch: 51/128
# Model parameters updated.
#
# Processing batch 148/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.6816
# Number of correct predictions in this batch: 50/128
# Model parameters updated.
#
# Processing batch 149/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.6091
# Number of correct predictions in this batch: 44/128
# Model parameters updated.
#
# Processing batch 150/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7941
# Number of correct predictions in this batch: 37/128
# Model parameters updated.
#
# Processing batch 151/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7000
# Number of correct predictions in this batch: 43/128
# Model parameters updated.
#
# Processing batch 152/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.6755
# Number of correct predictions in this batch: 53/128
# Model parameters updated.
#
# Processing batch 153/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7651
# Number of correct predictions in this batch: 41/128
# Model parameters updated.
#
# Processing batch 154/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.5656
# Number of correct predictions in this batch: 55/128
# Model parameters updated.
#
# Processing batch 155/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.8015
# Number of correct predictions in this batch: 41/128
# Model parameters updated.
#
# Processing batch 156/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7066
# Number of correct predictions in this batch: 48/128
# Model parameters updated.
#
# Processing batch 157/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.6006
# Number of correct predictions in this batch: 49/128
# Model parameters updated.
#
# Processing batch 158/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.6308
# Number of correct predictions in this batch: 46/128
# Model parameters updated.
#
# Processing batch 159/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.5534
# Number of correct predictions in this batch: 56/128
# Model parameters updated.
#
# Processing batch 160/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.6939
# Number of correct predictions in this batch: 49/128
# Model parameters updated.
#
# Processing batch 161/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.6856
# Number of correct predictions in this batch: 53/128
# Model parameters updated.
#
# Processing batch 162/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7152
# Number of correct predictions in this batch: 53/128
# Model parameters updated.
#
# Processing batch 163/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7996
# Number of correct predictions in this batch: 47/128
# Model parameters updated.
#
# Processing batch 164/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.6708
# Number of correct predictions in this batch: 53/128
# Model parameters updated.
#
# Processing batch 165/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.5166
# Number of correct predictions in this batch: 57/128
# Model parameters updated.
#
# Processing batch 166/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.6114
# Number of correct predictions in this batch: 53/128
# Model parameters updated.
#
# Processing batch 167/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.6743
# Number of correct predictions in this batch: 38/128
# Model parameters updated.
#
# Processing batch 168/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.5865
# Number of correct predictions in this batch: 48/128
# Model parameters updated.
#
# Processing batch 169/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.5239
# Number of correct predictions in this batch: 50/128
# Model parameters updated.
#
# Processing batch 170/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.6907
# Number of correct predictions in this batch: 52/128
# Model parameters updated.
#
# Processing batch 171/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7868
# Number of correct predictions in this batch: 42/128
# Model parameters updated.
#
# Processing batch 172/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.7275
# Number of correct predictions in this batch: 43/128
# Model parameters updated.
#
# Processing batch 173/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 1.6456
# ...
# Batch loss: 0.2654
# Number of correct predictions in this batch: 115/128
# Model parameters updated.
#
# Processing batch 258/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.3428
# Number of correct predictions in this batch: 115/128
# Model parameters updated.
#
# Processing batch 259/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.3257
# Number of correct predictions in this batch: 112/128
# Model parameters updated.
#
# Processing batch 260/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.3200
# Number of correct predictions in this batch: 110/128
# Model parameters updated.
#
# Processing batch 261/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.3482
# Number of correct predictions in this batch: 111/128
# Model parameters updated.
#
# Processing batch 262/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.3913
# Number of correct predictions in this batch: 109/128
# Model parameters updated.
#
# Processing batch 263/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.3333
# Number of correct predictions in this batch: 114/128
# Model parameters updated.
#
# Processing batch 264/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.3331
# Number of correct predictions in this batch: 110/128
# Model parameters updated.
#
# Processing batch 265/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.2825
# Number of correct predictions in this batch: 115/128
# Model parameters updated.
#
# Processing batch 266/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.2406
# Number of correct predictions in this batch: 117/128
# Model parameters updated.
#
# Processing batch 267/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.2970
# Number of correct predictions in this batch: 115/128
# Model parameters updated.
#
# Processing batch 268/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.2832
# Number of correct predictions in this batch: 116/128
# Model parameters updated.
#
# Processing batch 269/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.3375
# Number of correct predictions in this batch: 115/128
# Model parameters updated.
#
# Processing batch 270/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.2442
# Number of correct predictions in this batch: 113/128
# Model parameters updated.
#
# Processing batch 271/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.3332
# Number of correct predictions in this batch: 113/128
# Model parameters updated.
#
# Processing batch 272/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.2112
# Number of correct predictions in this batch: 121/128
# Model parameters updated.
#
# Processing batch 273/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.2931
# Number of correct predictions in this batch: 114/128
# Model parameters updated.
#
# Processing batch 274/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.4196
# Number of correct predictions in this batch: 112/128
# Model parameters updated.
#
# Processing batch 275/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.2929
# Number of correct predictions in this batch: 115/128
# Model parameters updated.
#
# Processing batch 276/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.2919
# Number of correct predictions in this batch: 115/128
# Model parameters updated.
#
# Processing batch 277/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.2908
# Number of correct predictions in this batch: 115/128
# Model parameters updated.
#
# Processing batch 278/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.4595
# Number of correct predictions in this batch: 104/128
# Model parameters updated.
#
# Processing batch 279/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.2913
# Number of correct predictions in this batch: 118/128
# Model parameters updated.
#
# Processing batch 280/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.3399
# Number of correct predictions in this batch: 112/128
# Model parameters updated.
#
# Processing batch 281/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.6320
# Number of correct predictions in this batch: 103/128
# Model parameters updated.
#
# Processing batch 282/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.3031
# Number of correct predictions in this batch: 115/128
# Model parameters updated.
#
# Processing batch 283/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.3708
# Number of correct predictions in this batch: 110/128
# Model parameters updated.
#
# Processing batch 284/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.3912
# Number of correct predictions in this batch: 112/128
# Model parameters updated.
#
# Processing batch 285/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.3214
# Number of correct predictions in this batch: 110/128
# Model parameters updated.
#
# Processing batch 286/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.4334
# Number of correct predictions in this batch: 108/128
# Model parameters updated.
#
# Processing batch 287/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.3846
# Number of correct predictions in this batch: 114/128
# Model parameters updated.
#
# Processing batch 288/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.2698
# Number of correct predictions in this batch: 117/128
# Model parameters updated.
#
# Processing batch 289/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.3758
# Number of correct predictions in this batch: 114/128
# Model parameters updated.
#
# Processing batch 290/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.3016
# Number of correct predictions in this batch: 116/128
# Model parameters updated.
#
# Processing batch 291/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.2768
# Number of correct predictions in this batch: 117/128
# Model parameters updated.
#
# Processing batch 292/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.1360
# Number of correct predictions in this batch: 123/128
# Model parameters updated.
#
# Processing batch 293/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.3016
# Number of correct predictions in this batch: 114/128
# Model parameters updated.
#
# Processing batch 294/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.4631
# Number of correct predictions in this batch: 104/128
# Model parameters updated.
#
# Processing batch 295/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.4825
# Number of correct predictions in this batch: 109/128
# Model parameters updated.
#
# Processing batch 296/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.4816
# Number of correct predictions in this batch: 110/128
# Model parameters updated.
#
# Processing batch 297/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.2103
# Number of correct predictions in this batch: 118/128
# Model parameters updated.
#
# Processing batch 298/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.3980
# Number of correct predictions in this batch: 111/128
# Model parameters updated.
#
# Processing batch 299/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.4265
# Number of correct predictions in this batch: 106/128
# Model parameters updated.
#
# Processing batch 300/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.3922
# Number of correct predictions in this batch: 110/128
# Model parameters updated.
#
# Processing batch 301/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.2773
# Number of correct predictions in this batch: 115/128
# Model parameters updated.
#
# Processing batch 302/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.3761
# Number of correct predictions in this batch: 112/128
# Model parameters updated.
#
# Processing batch 303/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.2645
# Number of correct predictions in this batch: 115/128
# Model parameters updated.
#
# Processing batch 304/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.3821
# Number of correct predictions in this batch: 111/128
# Model parameters updated.
#
# Processing batch 305/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.4438
# Number of correct predictions in this batch: 109/128
# Model parameters updated.
#
# Processing batch 306/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.3282
# Number of correct predictions in this batch: 113/128
# Model parameters updated.
#
# Processing batch 307/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.2781
# Number of correct predictions in this batch: 116/128
# Model parameters updated.
#
# Processing batch 308/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.2910
# Number of correct predictions in this batch: 116/128
# Model parameters updated.
#
# Processing batch 309/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.4078
# Number of correct predictions in this batch: 103/128
# Model parameters updated.
#
# Processing batch 310/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.3376
# Number of correct predictions in this batch: 113/128
# Model parameters updated.
#
# Processing batch 311/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.4036
# Number of correct predictions in this batch: 110/128
# Model parameters updated.
#
# Processing batch 312/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.2853
# Number of correct predictions in this batch: 114/128
# Model parameters updated.
#
# Processing batch 313/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.2526
# Number of correct predictions in this batch: 119/128
# Model parameters updated.
#
# Processing batch 314/352
# Input batch shape: torch.Size([128, 3, 32, 32]), Target batch shape: torch.Size([128])
# Optimizer gradients zeroed.
# Prediction shape: torch.Size([128, 10])
# Batch loss: 0.3148
# Number of correct predictions in this batch: 112/128

# %% [markdown]
# Once the model is trained we run it on the test set to obtain our final accuracy.
# Note that we can only look at the test set once, everything else would lead to overfitting. So you _must_ ignore the test set while developing your model!

# %%
test_loss, test_acc = run_epoch(resnet, None, dataloaders['test'], train=False)
print(f"Test loss: {test_loss:.1e}, accuracy: {test_acc * 100:.2f}%")

# %% [markdown]
# That's almost what was reported in the paper (92.49%) and we didn't even train on the full training set.

# %% [markdown]
# # Optional task: Squeeze out all the juice!

# %% [markdown]
# Can you do even better? Have a look at [A Recipe for Training Neural Networks](https://karpathy.github.io/2019/04/25/recipe/) and some state-of-the-art architectures such as [EfficientNet architecture](https://ai.googleblog.com/2019/05/efficientnet-improving-accuracy-and.html). Play around with the possibilities PyTorch offers you and see how close you can get to the [state of the art on CIFAR-10](https://paperswithcode.com/sota/image-classification-on-cifar-10).
